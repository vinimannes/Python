# %%
import requests

# %%
import bs4

# %%
res = requests.get('https://en.wikipedia.org/wiki/Sociedade_Esportiva_Palmeiras')

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Sociedade Esportiva Palmeiras - Wikipedia</title>
# ...

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">History</span>,
#  <span class="toctext">Palestra is born – opening game</span>,
#  <span class="toctext">1920–1945 – First state title and purchase of the stadium</span>,
#  <span class="toctext">A Leader Dies, A Champion is Born</span>,
#  <span class="toctext">International Clubs’ Tournament (Copa Rio): The first club Intercontinental Cup and the embryo of modern club international championships</span>,
#  <span class="toctext">The Academy, the Brazilian giant</span>,
#  <span class="toctext">1980s: The lost decade</span>,
#  <span class="toctext">The end of the 20th century – The Greatest in Brazil</span>,
#  <span class="toctext">1999 – The first Copa Libertadores trophy</span>,
#  <span class="toctext">2000 – Four finals disputed</span>,
#  <span class="toctext">2000s - Difficult years</span>,
#  <span class="toctext">Allianz Parque</span>,
#  <span class="toctext">2012 Copa do Brasil: Undefeated Winners</span>,
# ...

# %%
first_item = soup.select('.toctext')[0]

# %%
first_item
# Out:
# <span class="toctext">History</span>

# %%
first_item.text
# Out:
# 'History'

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# History
# Palestra is born – opening game
# 1920–1945 – First state title and purchase of the stadium
# A Leader Dies, A Champion is Born
# International Clubs’ Tournament (Copa Rio): The first club Intercontinental Cup and the embryo of modern club international championships
# The Academy, the Brazilian giant
# 1980s: The lost decade
# The end of the 20th century – The Greatest in Brazil
# 1999 – The first Copa Libertadores trophy
# 2000 – Four finals disputed
# 2000s - Difficult years
# Allianz Parque
# 2012 Copa do Brasil: Undefeated Winners
# Relegation and promotion
# 2015 reformulation and Copa do Brasil title
# 2016–2018: Palmeiras back on top of Brazilian football
# 2016 Campeonato Brasileiro Série A Champions
# Decacampeão of Série A (10th championship)
# 2020 – Treble: Campeonato Paulista, Copa do Brasil and Copa Libertadores Winners
# 2021 – Second consecutive Copa Libertadores and IFFHS men’s world best club ranking winners
# Current season (2022)
# Stadium
# ...
