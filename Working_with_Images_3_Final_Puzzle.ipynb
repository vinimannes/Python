# %%
from PIL import Image

# %%
words = Image.open('word_matrix.png')

# %%
mask = Image.open('mask.png')

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211CC7A0CD0>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x211CD32EAF0>

# %%
# Does not work because I need to resize
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211CCA7B580>

# %%
words = Image.open('word_matrix.png')

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211CD320550>

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251 at 0x211CD32EAF0>

# %%
words.size
# Out:
# (1015, 559)

# %%
mask = mask.resize((1015, 559))

# %%
mask.size
# Out:
# (1015, 559)

# %%
mask.putalpha(200)

# %%
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=1015x559 at 0x211CD320A30>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559 at 0x211CD320550>
